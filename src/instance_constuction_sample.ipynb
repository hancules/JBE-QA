# %%
import datasets
from config import TOKEN, COMMIT, format_question, dataset_name

jbeqa = datasets.load_dataset("nguyenthanhasia/japanese-bar-exam-qa-v2", token=TOKEN, revision=COMMIT)
instance = jbeqa['test'][0]
instance
# Out:
# {'id': '令和６年-民法-18-5',
#  'year': '令和６年',
#  'subject': 'Civil Law',
#  'subject_jp': '民法',
#  'theme': '債務不履行による損害賠償',
#  'question_type': 'CSQ',
#  'instruction': '判例の趣旨に照らし記述が正しいか',
#  'remark': '',
#  'label': 'N',
#  'lead_in': '',
#  'question': '契約の一方当事者Aが、契約締結に先立ち、信義則上の説明義務に違反して、当該契約を締結するか否かに関する判断に影響を及ぼすべき情報を他方当事者Bに提供しなかったときは、Aは、Bに対し、Bが当該契約を締結したことにより受けた損害につき当該契約上の債務不履行による賠償責任を負う。',
#  'answer': False}

# %%
print(format_question(instance))
# Out:
# 科目：民法
# 債務不履行による損害賠償について
# 判例の趣旨に照らして、次の記述は正しいか否か。
# 契約の一方当事者Aが、契約締結に先立ち、信義則上の説明義務に違反して、当該契約を締結するか否かに関する判断に影響を及ぼすべき情報を他方当事者Bに提供しなかったときは、Aは、Bに対し、Bが当該契約を締結したことにより受けた損害につき当該契約上の債務不履行による賠償責任を負う。
